# %% [markdown]
# ### the following notebook takes merge the previous dataset with a csv containing information regarding salient events

# %%
# libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Data                                   salient_events.csv
# Presentation                           sentiment analysis code
# README.md                              to_ingest
# Sentiment Analysis Covid Vaccine.ipynb vt_cases_deaths
# geopy_location_mapping.ipynb           vt_cases_deaths_complete
# merge_cases_deaths.ipynb               vt_cases_deaths_complete.csv
# merge_cases_deaths_complete.ipynb      vt_cleaned_sentiment
# merge_events.ipynb

# %%
pd.set_option('display.max_columns', None)

# %%
# dataframe
df      =  pd.read_csv("Data/vt_cases_deaths_complete.csv")  
events  = pd.read_csv("Data/salient_events.csv")

# %%
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df.tail()
# Out:
#                        id                  user_name  user_location  \
# 9335  1382253724878344196                     Roopam         Ranchi
# 9336  1382250817189597189               moneycontrol         Mumbai
# 9337  1382250738760384515                     ET NOW          India
# 9338  1382248484259123205  Russian Mission in Geneva         Geneve
# 9339  1382246393532801026                Mora Mosese  NtswanaTsatsi
#
#                                        user_description         user_created  \
# 9335  Be Ur Kind of Crazy....Someone out there will ...  2019-08-19 14:55:44
# 9336  Moneycontrol is India’s No. 1 financial portal...  2009-08-26 07:55:29
# 9337  Youtube: https://t.co/u54RR8zcQ8 Facebook: htt...  2010-12-10 12:49:29
# 9338  Постпредство России при Отделении ООН и др. ме...  2011-07-26 08:40:47
# 9339                               #MoAfrika - #MoSotho  2019-12-06 11:11:07
#
#       user_followers  user_friends  user_favourites  user_verified  \
# ...

# %%
events
# Out:
#           date  date_plus_10  \
# 0   08-12-2020    13-12-2020
# 1   14-12-2020    22-12-2020
# 2   23-12-2020    28-12-2020
# 3     29-12-20    30-12-2020
# 4     31-12-20    04-01-2021
# 5   05-01-2021    21-01-2021
# 6   22-01-2021    03-02-2021
# 7   25-02-2021     9-03-2021
# 8   10-03-2021    20-03-2021
# 9   12-04-2021    17-04-2021
# 10  05-04-2021   22-04-2021
#
#                                                 event  \
# 0     Biden promises 100 million vaccines in 100 days
# 1   United Kingdom authorities reported a SARS-CoV...
# 2   US Buys More Pfizer Vaccine - The Trump admini...
# 3   First US Case of New COVID-19 Variant Found in...
# 4   US Falls Short of Goal to Give 20 Million Vacc...
# 5   WHO’s Strategic Advisory Group of Experts on I...
# 6   Boris Johnson announces that Covid UK Variant ...
# 7   All India Institute of Medical Sciences said t...
# 8   Vaccination sites across the UK delivered almo...
# 9   India authorizes use of Russia’s Sputnik V vac...
# ...

# %%
events['date'] = pd.to_datetime(events['date'], dayfirst=True).dt.date
events['date_plus_10'] = pd.to_datetime(events['date_plus_10'], dayfirst=True).dt.date

events
# Out:
#           date date_plus_10  \
# 0   2020-12-08   2020-12-13
# 1   2020-12-14   2020-12-22
# 2   2020-12-23   2020-12-28
# 3   2020-12-29   2020-12-30
# 4   2020-12-31   2021-01-04
# 5   2021-01-05   2021-01-21
# 6   2021-01-22   2021-02-03
# 7   2021-02-25   2021-03-09
# 8   2021-03-10   2021-03-20
# 9   2021-04-12   2021-04-17
# 10  2021-04-05   2021-04-22
#
#                                                 event  \
# 0     Biden promises 100 million vaccines in 100 days
# 1   United Kingdom authorities reported a SARS-CoV...
# 2   US Buys More Pfizer Vaccine - The Trump admini...
# 3   First US Case of New COVID-19 Variant Found in...
# 4   US Falls Short of Goal to Give 20 Million Vacc...
# 5   WHO’s Strategic Advisory Group of Experts on I...
# 6   Boris Johnson announces that Covid UK Variant ...
# 7   All India Institute of Medical Sciences said t...
# 8   Vaccination sites across the UK delivered almo...
# 9   India authorizes use of Russia’s Sputnik V vac...
# ...

# %%
df.user_country
# Out:
# 0             Pakistan
# 1               Turkey
# 2       United Kingdom
# 3                Egypt
# 4          Netherlands
#              ...
# 9335             India
# 9336             India
# 9337             India
# 9338       Switzerland
# 9339      South Africa
# Name: user_country, Length: 9340, dtype: object

# %%
print(type(df.loc[0,'date']), type(events.loc[0,'date_plus_10']))
#United Kingdom
#United States
#India
# Out:
# <class 'datetime.date'> <class 'datetime.date'>

# %%
for index, row in df.iterrows():
    if df.loc[index,'date'] <= events.loc[0,'date_plus_10'] and df.loc[index,'user_country'] == 'United States':
        df.loc[index,'event'] = events.loc[0,'event']
        df.loc[index,'link'] = events.loc[0,'newspaper_link']
    elif df.loc[index,'date'] > events.loc[0,'date_plus_10'] and df.loc[index,'date'] <= events.loc[1,'date_plus_10'] and df.loc[index,'user_country'] == 'United Kingdom':
        df.loc[index,'event'] = events.loc[1,'event']
        df.loc[index,'link'] = events.loc[1,'newspaper_link'] 
    elif df.loc[index,'date'] > events.loc[1,'date_plus_10'] and df.loc[index,'date'] <= events.loc[2,'date_plus_10'] and df.loc[index,'user_country'] == 'United States':
        df.loc[index,'event'] = events.loc[2,'event']
        df.loc[index,'link'] = events.loc[2,'newspaper_link']
    elif df.loc[index,'date'] > events.loc[2,'date_plus_10'] and df.loc[index,'date'] <= events.loc[3,'date_plus_10'] and (df.loc[index,'user_country'] == 'United States' or df.loc[index,'user_country'] == 'United Kingdom'):
        df.loc[index,'event'] = events.loc[3,'event']
        df.loc[index,'link'] = events.loc[3,'newspaper_link']
    elif df.loc[index,'date'] > events.loc[3,'date_plus_10'] and df.loc[index,'date'] <= events.loc[4,'date_plus_10'] and df.loc[index,'user_country'] == 'United States':
        df.loc[index,'event'] = events.loc[4,'event']
        df.loc[index,'link'] = events.loc[4,'newspaper_link']
    elif df.loc[index,'date'] > events.loc[4,'date_plus_10'] and df.loc[index,'date'] <= events.loc[5,'date_plus_10']:
        df.loc[index,'event'] = events.loc[5,'event']
        df.loc[index,'link'] = events.loc[5,'newspaper_link']    
    elif df.loc[index,'date'] > events.loc[5,'date_plus_10'] and df.loc[index,'date'] <= events.loc[6,'date_plus_10'] and df.loc[index,'user_country'] == 'United Kingdom':
        df.loc[index,'event'] = events.loc[6,'event']
        df.loc[index,'link'] = events.loc[6,'newspaper_link']  
    elif df.loc[index,'date'] > events.loc[6,'date_plus_10'] and df.loc[index,'date'] <= events.loc[7,'date_plus_10'] and df.loc[index,'user_country'] == 'India':
        df.loc[index,'event'] = events.loc[7,'event']
        df.loc[index,'link'] = events.loc[7,'newspaper_link'] 
    elif df.loc[index,'date'] > events.loc[7,'date_plus_10'] and df.loc[index,'date'] <= events.loc[8,'date_plus_10'] and df.loc[index,'user_country'] == 'United Kingdom':
        df.loc[index,'event'] = events.loc[8,'event']
        df.loc[index,'link'] = events.loc[8,'newspaper_link'] 
    elif df.loc[index,'date'] > events.loc[8,'date_plus_10'] and df.loc[index,'date'] <= events.loc[9,'date_plus_10'] and df.loc[index,'user_country'] == 'India':
        df.loc[index,'event'] = events.loc[9,'event']
        df.loc[index,'link'] = events.loc[9,'newspaper_link'] 
    elif df.loc[index,'date'] > events.loc[9,'date_plus_10'] and df.loc[index,'date'] <= events.loc[10,'date_plus_10'] and (df.loc[index,'user_country'] == 'United States' or df.loc[index,'user_country'] == 'United Kingdom'):
        df.loc[index,'link'] = events.loc[10,'newspaper_link']
    else:
        df.loc[index,'event'] = events.loc[10,'event']
        df.loc[index,'link'] = events.loc[10,'newspaper_link']

# %%
df.head(50)
# Out:
#                      id                                      user_name  \
# 0   1337842295857623042                                   Ch.Amjad Ali
# 1   1337783770070409218                                          ILKHA
# 2   1337760271151063040                                    Andy Thomas
# 3   1337727767551553536                               Daily News Egypt
# 4   1340571472025141248                                         IP_Man
# 5   1338574693087936513                            Prof. Manish Thakur
# 6   1338555378448076803                          Aru Sivananthan 🇬🇧 🇦🇺
# 7   1338551175587786752                                   India Blooms
# 8   1338548332218630144                                    Evan Webeck
# 9   1338546341404930050                                      Human_9.0
# 10  1338542633354924035                     Kraken-Elect AsuAdanac 🇨🇦💙
# 11  1338514087005794305                                AFP News Agency
# ...

# %%
df.tail()
# Out:
#                        id                  user_name  user_location  \
# 9335  1382253724878344196                     Roopam         Ranchi
# 9336  1382250817189597189               moneycontrol         Mumbai
# 9337  1382250738760384515                     ET NOW          India
# 9338  1382248484259123205  Russian Mission in Geneva         Geneve
# 9339  1382246393532801026                Mora Mosese  NtswanaTsatsi
#
#                                        user_description         user_created  \
# 9335  Be Ur Kind of Crazy....Someone out there will ...  2019-08-19 14:55:44
# 9336  Moneycontrol is India’s No. 1 financial portal...  2009-08-26 07:55:29
# 9337  Youtube: https://t.co/u54RR8zcQ8 Facebook: htt...  2010-12-10 12:49:29
# 9338  Постпредство России при Отделении ООН и др. ме...  2011-07-26 08:40:47
# 9339                               #MoAfrika - #MoSotho  2019-12-06 11:11:07
#
#       user_followers  user_friends  user_favourites  user_verified  \
# ...

# %%
df.to_csv('Data/vt_cd_events.csv', index = False)
