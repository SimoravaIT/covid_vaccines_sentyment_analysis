# %% [markdown]
# ### the following notebook takes as an input the vt_cleaned_sentiment.csv with the results of the sentiment analysis and merge data regarding cases and deaths due to covid.
#
# ### For the merge the time range considered is from 2020-12-12 to 2021-03-14

# %%
# libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Data                                   merge_cases_deaths_complete.ipynb
# Sentiment Analysis Covid Vaccine.ipynb merge_events.ipynb
# geopy_location_mapping.ipynb           sentiment analysis code
# merge_cases_deaths.ipynb

# %%
pd.set_option('display.max_columns', None)

# %%
# dataframe
df       =  pd.read_csv("Data/vt_cleaned_sentiment_with_country.csv")  
cas_dea  = pd.read_csv("Data/daily-covid-cases-deaths.csv")

# %%
df.head()
# Out:
#   Unnamed: 0                   id         user_name user_location  \
# 0          9  1337842295857623042      Ch.Amjad Ali     Islamabad
# 1         12  1337815730486702087              WION         India
# 2         17  1337783770070409218             ILKHA       Türkiye
# 3         30  1337760271151063040       Andy Thomas        London
# 4         44  1337727767551553536  Daily News Egypt         Egypt
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 1  #WION: World Is One | Welcome to India’s first...  2016-03-21 03:44:54
# 2     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 3             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 4  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
#
#   user_followers user_friends user_favourites user_verified  \
# 0            671         2368           20469         False
# 1         292510           91            7531          True
# 2           4056            6               3          True
# 3           1151         4301           95963         False
# 4         278080          116             765          True
#
#                   date                                               text  \
# 0  2020-12-12 19:30:33  #CovidVaccine \n\nStates will start getting #C...
# 1  2020-12-12 17:45:00  The agency also released new information for h...
# 2  2020-12-12 15:38:00  Coronavirus: Iran reports 8,201 new cases, 221...
# 3  2020-12-12 14:04:37  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 4  2020-12-12 11:55:28  #FDA authorizes #PfizerBioNTech #coronavirus v...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 1                                                NaN            TweetDeck
# 2          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 3                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 4           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 1        0        18      False  [78.6677428, 22.3511148]
# 2        3         5      False  [34.9249653, 38.9597594]
# 3        0         2      False  [-0.1276474, 51.5073219]
# 4        1         1      False  [29.2675469, 26.2540493]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 1  22.3511148, 78.6677428           India
# 2  38.9597594, 34.9249653          Turkey
# 3  51.5073219, -0.1276474  United Kingdom
# 4  26.2540493, 29.2675469           Egypt
#
#                                        modified_text  sent_score sentiment
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 1  The agency also released new information for h...    0.136364  positive
# 2  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 3  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 4  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral

# %%
df = df.dropna()

# %%
# requires strictly string, nan are class float
# will produce an error
for line in df['date']:
  if type(line) == float:
    print(line)
    break
print('no na')
# Out:
# no na

# %%
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df.head()
# Out:
#   Unnamed: 0                   id         user_name user_location  \
# 0          9  1337842295857623042      Ch.Amjad Ali     Islamabad
# 2         17  1337783770070409218             ILKHA       Türkiye
# 3         30  1337760271151063040       Andy Thomas        London
# 4         44  1337727767551553536  Daily News Egypt         Egypt
# 5         45  1340571472025141248            IP_Man       America
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 2     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 3             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 4  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 5  One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
#
#   user_followers user_friends user_favourites user_verified        date  \
# 0            671         2368           20469         False  2020-12-12
# 2           4056            6               3          True  2020-12-12
# 3           1151         4301           95963         False  2020-12-12
# 4         278080          116             765          True  2020-12-12
# 5            625          477           14475         False  2020-12-20
#
#                                                 text  \
# 0  #CovidVaccine \n\nStates will start getting #C...
# 2  Coronavirus: Iran reports 8,201 new cases, 221...
# 3  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 4  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 5  When The #CovidVaccine \nPoisons Enough Of The...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 2          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 3                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 4           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
# 5                     ['CovidVaccine', 'BellsPalsy']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 2        3         5      False  [34.9249653, 38.9597594]
# 3        0         2      False  [-0.1276474, 51.5073219]
# 4        1         1      False  [29.2675469, 26.2540493]
# 5        0         0      False   [5.9799001, 51.4371483]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 2  38.9597594, 34.9249653          Turkey
# 3  51.5073219, -0.1276474  United Kingdom
# 4  26.2540493, 29.2675469           Egypt
# 5   51.4371483, 5.9799001     Netherlands
#
#                                        modified_text  sent_score sentiment
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 2  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 3  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 4  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 5  When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral

# %%
# range date column
df.dtypes
# Out:
# Unnamed: 0            object
# id                    object
# user_name             object
# user_location         object
# user_description      object
# user_created          object
# user_followers        object
# user_friends          object
# user_favourites       object
# user_verified         object
# date                  object
# text                  object
# hashtags              object
# source                object
# retweets              object
# favorites             object
# is_retweet            object
# user_coordinates      object
# user_coordinates2     object
# user_country          object
# modified_text         object
# sent_score           float64
# sentiment             object
# dtype: object

# %%
# requires strictly string, nan are class float
# will produce an error
df = df.dropna()

# %%
# requires strictly string, nan are class float
# will produce an error
for line in df['date']:
  if type(line) == float:
    print(line)
    break
print('no na')
# Out:
# no na

# %%
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')

# %%
df.dtypes
# Out:
# Unnamed: 0                   object
# id                           object
# user_name                    object
# user_location                object
# user_description             object
# user_created                 object
# user_followers               object
# user_friends                 object
# user_favourites              object
# user_verified                object
# date                 datetime64[ns]
# text                         object
# hashtags                     object
# source                       object
# retweets                     object
# favorites                    object
# is_retweet                   object
# user_coordinates             object
# user_coordinates2            object
# user_country                 object
# modified_text                object
# sent_score                  float64
# sentiment                    object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.sort_values(by='date').tail()
# Out:
#       Unnamed: 0                   id        user_name user_location  \
# 11357      65355  1385058720271327233  K.C. Ramamurthy     Bangalore
# 11358      65361  1385055253649936385  Hindustan Times         India
# 11359      65380  1385043173949415429       IndiaToday         India
# 11947      68039  1385097630628384768  Nairobi_Exposed         Kenya
# 10958      61942  1385060833827295237            Ketan         India
#
#                                         user_description         user_created  \
# 11357  Member of Parliament, Rajyasabha (Karnataka) |...  2020-07-15 10:56:08
# 11358  One of India's largest media companies. Latest...  2009-04-29 10:11:34
# 11359  Brings you news breaks: Exclusive political, e...  2009-02-02 07:21:54
# 11947                                              Media  2021-04-09 08:04:42
# 10958  Political & Social Analyst. Privileged to have...  2009-03-27 08:22:14
#
#       user_followers user_friends user_favourites user_verified       date  \
# 11357            336          283             995         False 2021-04-22
# 11358        7959130          129            2929          True 2021-04-22
# 11359        5604583          250            4438          True 2021-04-22
# 11947           1212          457             138         False 2021-04-22
# 10958           8231          181           34119         False 2021-04-22
#
#                                                     text  \
# 11357  Vaccination Works Incredibly Well, Data Show i...
# 11358  #Covaxin's efficacy of 78% was recorded agains...
# 11359  The result showed that #Covaxin's efficacy aga...
# 11947  @PrinceD57219228 @praj21582761 Some bad adviso...
# 10958  #COVID19 Private hospital chains in talks to o...
#
#                                                 hashtags               source  \
# 11357                            ['LargestVaccineDrive']  Twitter for Android
# 11358                             ['Covaxin', 'Covid19']            TweetDeck
# 11359                                  ['Covaxin', 'RE']            TweetDeck
# 11947                           ['agakhanandnmgcartels']      Twitter Web App
# 10958  ['COVID19', 'COVIDVaccines', 'PfizerVaccine', ...  Twitter for Android
#
#       retweets favorites is_retweet          user_coordinates  \
# 11357        0         0      False  [77.5912997, 12.9791198]
# 11358        3        21      False  [78.6677428, 22.3511148]
# 11359        6        28      False  [78.6677428, 22.3511148]
# 11947        0         0      False   [38.4313975, 1.4419683]
# 10958        0         0      False  [78.6677428, 22.3511148]
#
#             user_coordinates2 user_country  \
# 11357  12.9791198, 77.5912997        India
# 11358  22.3511148, 78.6677428        India
# 11359  22.3511148, 78.6677428        India
# 11947   1.4419683, 38.4313975        Kenya
# 10958  22.3511148, 78.6677428        India
#
#                                            modified_text  sent_score sentiment
# 11357  Vaccination Works Incredibly Well, Data Show i...    1.000000  positive
# 11358  #Covaxin's efficacy of 78% was recorded agains...    0.166667  positive
# 11359  The result showed that #Covaxin's efficacy aga...    0.000000   neutral
# 11947  @PrinceD57219228 @praj21582761 Some bad adviso...   -0.700000  negative
# 10958  #COVID19 Private hospital chains in talks to o...    0.000000   neutral

# %%
# range between 2020-12-12 and 2021-04-22

# %%
cas_dea.head(50)
# Out:
#          Entity Code         Day  Daily new confirmed cases of COVID-19  \
# 0   Afghanistan  AFG  2020-02-24                                    1.0
# 1   Afghanistan  AFG  2020-02-25                                    0.0
# 2   Afghanistan  AFG  2020-02-26                                    0.0
# 3   Afghanistan  AFG  2020-02-27                                    0.0
# 4   Afghanistan  AFG  2020-02-28                                    0.0
# 5   Afghanistan  AFG  2020-02-29                                    0.0
# 6   Afghanistan  AFG  2020-03-01                                    0.0
# 7   Afghanistan  AFG  2020-03-02                                    0.0
# 8   Afghanistan  AFG  2020-03-03                                    1.0
# 9   Afghanistan  AFG  2020-03-04                                    2.0
# 10  Afghanistan  AFG  2020-03-05                                    0.0
# 11  Afghanistan  AFG  2020-03-06                                    0.0
# 12  Afghanistan  AFG  2020-03-07                                    0.0
# 13  Afghanistan  AFG  2020-03-08                                    1.0
# 14  Afghanistan  AFG  2020-03-09                                    2.0
# 15  Afghanistan  AFG  2020-03-10                                    1.0
# 16  Afghanistan  AFG  2020-03-11                                    3.0
# 17  Afghanistan  AFG  2020-03-12                                    1.0
# 18  Afghanistan  AFG  2020-03-13                                    1.0
# 19  Afghanistan  AFG  2020-03-14                                    2.0
# 20  Afghanistan  AFG  2020-03-15                                    1.0
# 21  Afghanistan  AFG  2020-03-16                                    2.0
# 22  Afghanistan  AFG  2020-03-17                                    2.0
# 23  Afghanistan  AFG  2020-03-18                                    4.0
# 24  Afghanistan  AFG  2020-03-19                                    1.0
# 25  Afghanistan  AFG  2020-03-20                                    4.0
# 26  Afghanistan  AFG  2020-03-21                                    1.0
# 27  Afghanistan  AFG  2020-03-22                                    4.0
# 28  Afghanistan  AFG  2020-03-23                                    7.0
# 29  Afghanistan  AFG  2020-03-24                                    2.0
# 30  Afghanistan  AFG  2020-03-25                                   33.0
# 31  Afghanistan  AFG  2020-03-26                                    4.0
# 32  Afghanistan  AFG  2020-03-27                                   11.0
# 33  Afghanistan  AFG  2020-03-28                                   16.0
# 34  Afghanistan  AFG  2020-03-29                                   11.0
# 35  Afghanistan  AFG  2020-03-30                                   28.0
# 36  Afghanistan  AFG  2020-03-31                                   29.0
# 37  Afghanistan  AFG  2020-04-01                                   22.0
# 38  Afghanistan  AFG  2020-04-02                                   43.0
# 39  Afghanistan  AFG  2020-04-03                                   35.0
# 40  Afghanistan  AFG  2020-04-04                                   25.0
# 41  Afghanistan  AFG  2020-04-05                                   38.0
# 42  Afghanistan  AFG  2020-04-06                                   30.0
# 43  Afghanistan  AFG  2020-04-07                                   56.0
# 44  Afghanistan  AFG  2020-04-08                                   21.0
# 45  Afghanistan  AFG  2020-04-09                                   40.0
# 46  Afghanistan  AFG  2020-04-10                                   47.0
# 47  Afghanistan  AFG  2020-04-11                                   24.0
# 48  Afghanistan  AFG  2020-04-12                                   52.0
# 49  Afghanistan  AFG  2020-04-13                                   58.0
#
#     Daily new confirmed deaths due to COVID-19
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         1.0
# 28                                         0.0
# 29                                         0.0
# 30                                         1.0
# 31                                         1.0
# 32                                         0.0
# 33                                         1.0
# 34                                         0.0
# 35                                         0.0
# 36                                         0.0
# 37                                         0.0
# 38                                         0.0
# 39                                         4.0
# 40                                         2.0
# 41                                         2.0
# 42                                         3.0
# 43                                         1.0
# 44                                         0.0
# 45                                         1.0
# 46                                         1.0
# 47                                         0.0
# 48                                         1.0
# 49                                         3.0

# %%
cases  = cas_dea[['Day', 'Daily new confirmed cases of COVID-19']]
deaths = cas_dea[['Day', 'Daily new confirmed deaths due to COVID-19']]
cases.columns  = ['Date', 'Daily new confirmed cases of COVID-19']
deaths.columns = ['Date', 'Daily new confirmed deaths due to COVID-19']

# %%
# on the cases
cases = cases.groupby(by=["Date"]).sum()
cases.reset_index(level=0, inplace=True)
cases.head()
# Out:
#          Date  Daily new confirmed cases of COVID-19
# 0  2020-01-22                                    0.0
# 1  2020-01-23                                  411.0
# 2  2020-01-24                                 1175.0
# 3  2020-01-25                                 2004.0
# 4  2020-01-26                                 2803.0

# %%
type(cases)
#cases.date = cases.to_datetime(cases.date, format='%Y-%m-%d')
#cases.dtypes
# Out:
# pandas.core.frame.DataFrame

# %%
cases.Date = pd.to_datetime(cases.Date, format='%Y-%m-%d')

# %%
cases.sort_values(by='Date').head()
# Out:
#         Date  Daily new confirmed cases of COVID-19
# 0 2020-01-22                                    0.0
# 1 2020-01-23                                  411.0
# 2 2020-01-24                                 1175.0
# 3 2020-01-25                                 2004.0
# 4 2020-01-26                                 2803.0

# %%
cases.sort_values(by='Date').tail()
# Out:
#           Date  Daily new confirmed cases of COVID-19
# 486 2021-05-22                              4401278.0
# 487 2021-05-23                              3656636.0
# 488 2021-05-24                              3482499.0
# 489 2021-05-25                              4045310.0
# 490 2021-05-26                              4251903.0

# %%
deaths = deaths.groupby(by=["Date"]).sum()
deaths.reset_index(level=0, inplace=True)
deaths.Date = pd.to_datetime(deaths.Date, format='%Y-%m-%d')
deaths.sort_values(by='Date').head()
# Out:
#         Date  Daily new confirmed deaths due to COVID-19
# 0 2020-01-22                                         0.0
# 1 2020-01-23                                         4.0
# 2 2020-01-24                                        32.0
# 3 2020-01-25                                        64.0
# 4 2020-01-26                                        56.0

# %%
deaths.sort_values(by='Date').tail()
# Out:
#           Date  Daily new confirmed deaths due to COVID-19
# 486 2021-05-22                                     85207.0
# 487 2021-05-23                                     72901.0
# 488 2021-05-24                                     67103.0
# 489 2021-05-25                                     95834.0
# 490 2021-05-26                                     94744.0

# %%
# df time range available  2020-12-12 and 2021-04-22
# cases time range available 2020-01-23	 to 2021-03-14	
# deaths time range available 2020-01-23	to 2021-03-14	


### FOR THE MERGE CONSIDER THE RANGE 2020-12-12 TO 2021-03-14

# %%
def filter_date_range(data, string_name_column_date):
    
    start_date = "2020-12-12"
    end_date = "2021-04-22"

    after_start_date = data[string_name_column_date] >= start_date
    before_end_date = data[string_name_column_date] <= end_date
    between_two_dates = after_start_date & before_end_date
    filtered_dates = data.loc[between_two_dates]
    
    return filtered_dates

# %%
filt_df = filter_date_range(df, 'date')
filt_cases = filter_date_range(cases, 'Date')
filt_deaths = filter_date_range(deaths, 'Date')

# %%
### FOR THE MERGE CONSIDER THE RANGE 2020-12-12 TO 2021-03-14
filt_df.date.head(1)
# Out:
# 0   2020-12-12
# Name: date, dtype: datetime64[ns]

# %%
filt_df.date.tail(1)
# Out:
# 12227   2021-04-14
# Name: date, dtype: datetime64[ns]

# %%
### FOR THE MERGE CONSIDER THE RANGE 2020-12-12 TO 2021-03-14
filt_cases.Date.head(1)
# Out:
# 325   2020-12-12
# Name: Date, dtype: datetime64[ns]

# %%
filt_cases.Date.tail(1)
# Out:
# 456   2021-04-22
# Name: Date, dtype: datetime64[ns]

# %%
### FOR THE MERGE CONSIDER THE RANGE 2020-12-12 TO 2021-03-14
filt_deaths.Date.head(1)
# Out:
# 325   2020-12-12
# Name: Date, dtype: datetime64[ns]

# %%
filt_deaths.head()
# Out:
#           Date  Daily new confirmed deaths due to COVID-19
# 325 2020-12-12                                     78057.0
# 326 2020-12-13                                     55661.0
# 327 2020-12-14                                     68538.0
# 328 2020-12-15                                    103882.0
# 329 2020-12-16                                    101136.0

# %%
filt_deaths.Date.tail(1)
# Out:
# 456   2021-04-22
# Name: Date, dtype: datetime64[ns]

# %%
filt_cases.columns = ['date', 'Daily new confirmed cases of COVID-19']
filt_cases
# Out:
#           date  Daily new confirmed cases of COVID-19
# 325 2020-12-12                              4675036.0
# 326 2020-12-13                              3913949.0
# 327 2020-12-14                              3852575.0
# 328 2020-12-15                              4698877.0
# 329 2020-12-16                              5398641.0
# ..         ...                                    ...
# 452 2021-04-18                              5294163.0
# 453 2021-04-19                              5330654.0
# 454 2021-04-20                              6571264.0
# 455 2021-04-21                              6847949.0
# 456 2021-04-22                              6925425.0
#
# [132 rows x 2 columns]

# %%
filt_df.shape
# Out:
# (9340, 23)

# %%
filt_df.head()
# Out:
#   Unnamed: 0                   id         user_name user_location  \
# 0          9  1337842295857623042      Ch.Amjad Ali     Islamabad
# 2         17  1337783770070409218             ILKHA       Türkiye
# 3         30  1337760271151063040       Andy Thomas        London
# 4         44  1337727767551553536  Daily News Egypt         Egypt
# 5         45  1340571472025141248            IP_Man       America
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 2     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 3             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 4  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 5  One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
#
#   user_followers user_friends user_favourites user_verified       date  \
# 0            671         2368           20469         False 2020-12-12
# 2           4056            6               3          True 2020-12-12
# 3           1151         4301           95963         False 2020-12-12
# 4         278080          116             765          True 2020-12-12
# 5            625          477           14475         False 2020-12-20
#
#                                                 text  \
# 0  #CovidVaccine \n\nStates will start getting #C...
# 2  Coronavirus: Iran reports 8,201 new cases, 221...
# 3  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 4  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 5  When The #CovidVaccine \nPoisons Enough Of The...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 2          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 3                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 4           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
# 5                     ['CovidVaccine', 'BellsPalsy']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 2        3         5      False  [34.9249653, 38.9597594]
# 3        0         2      False  [-0.1276474, 51.5073219]
# 4        1         1      False  [29.2675469, 26.2540493]
# 5        0         0      False   [5.9799001, 51.4371483]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 2  38.9597594, 34.9249653          Turkey
# 3  51.5073219, -0.1276474  United Kingdom
# 4  26.2540493, 29.2675469           Egypt
# 5   51.4371483, 5.9799001     Netherlands
#
#                                        modified_text  sent_score sentiment
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 2  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 3  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 4  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 5  When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral

# %%
filt_df['cases'] = 0
filt_df.reset_index(level=0, inplace=True)
del filt_df['Unnamed: 0']
del filt_df['index']
filt_df.head()
# Out:
#                     id         user_name user_location  \
# 0  1337842295857623042      Ch.Amjad Ali     Islamabad
# 1  1337783770070409218             ILKHA       Türkiye
# 2  1337760271151063040       Andy Thomas        London
# 3  1337727767551553536  Daily News Egypt         Egypt
# 4  1340571472025141248            IP_Man       America
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 1     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 2             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 3  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 4  One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
#
#   user_followers user_friends user_favourites user_verified       date  \
# 0            671         2368           20469         False 2020-12-12
# 1           4056            6               3          True 2020-12-12
# 2           1151         4301           95963         False 2020-12-12
# 3         278080          116             765          True 2020-12-12
# 4            625          477           14475         False 2020-12-20
#
#                                                 text  \
# 0  #CovidVaccine \n\nStates will start getting #C...
# 1  Coronavirus: Iran reports 8,201 new cases, 221...
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 4  When The #CovidVaccine \nPoisons Enough Of The...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 1          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 2                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 3           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
# 4                     ['CovidVaccine', 'BellsPalsy']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 1        3         5      False  [34.9249653, 38.9597594]
# 2        0         2      False  [-0.1276474, 51.5073219]
# 3        1         1      False  [29.2675469, 26.2540493]
# 4        0         0      False   [5.9799001, 51.4371483]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 1  38.9597594, 34.9249653          Turkey
# 2  51.5073219, -0.1276474  United Kingdom
# 3  26.2540493, 29.2675469           Egypt
# 4   51.4371483, 5.9799001     Netherlands
#
#                                        modified_text  sent_score sentiment  \
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 1  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 4  When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral
#
#    cases
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
'''
for index, row in df.iterrows():
    while True:
        try:
            #print(row)
            #print(row.date)
            temp = filt_cases.loc[filt_cases['Date'] == row.date]
            #print(temp.iloc[0])
            #print(temp.iloc[0]['Daily new confirmed cases of COVID-19'])
            #print(type(temp))
            #sub_df.iloc[0]['A']
            #df.iloc[index]['cases'] = temp.iloc[0]['Daily new confirmed cases of COVID-19']
            #print(temp.iloc[0]['Daily new confirmed cases of COVID-19'])
            df['cases'][index] = temp.iloc[0]['Daily new confirmed cases of COVID-19']
            #df.iloc[index].loc['cases'] = temp.iloc[0]['Daily new confirmed cases of COVID-19']
        except ValueError:
            print(row)
            break
'''
# Out:
# "\nfor index, row in df.iterrows():\n    while True:\n        try:\n            #print(row)\n            #print(row.date)\n            temp = filt_cases.loc[filt_cases['Date'] == row.date]\n            #print(temp.iloc[0])\n            #print(temp.iloc[0]['Daily new confirmed cases of COVID-19'])\n            #print(type(temp))\n            #sub_df.iloc[0]['A']\n            #df.iloc[index]['cases'] = temp.iloc[0]['Daily new confirmed cases of COVID-19']\n            #print(temp.iloc[0]['Daily new confirmed cases of COVID-19'])\n            df['cases'][index] = temp.iloc[0]['Daily new confirmed cases of COVID-19']\n            #df.iloc[index].loc['cases'] = temp.iloc[0]['Daily new confirmed cases of COVID-19']\n        except ValueError:\n            print(row)\n            break\n"

# %%
for index, row in filt_df.iterrows():
    filt_df.loc[index,'cases'] = filt_cases.loc[filt_cases['date'] == row.date].iloc[0]['Daily new confirmed cases of COVID-19']

# %%
filt_df.head()
# Out:
#                     id         user_name user_location  \
# 0  1337842295857623042      Ch.Amjad Ali     Islamabad
# 1  1337783770070409218             ILKHA       Türkiye
# 2  1337760271151063040       Andy Thomas        London
# 3  1337727767551553536  Daily News Egypt         Egypt
# 4  1340571472025141248            IP_Man       America
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 1     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 2             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 3  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 4  One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
#
#   user_followers user_friends user_favourites user_verified       date  \
# 0            671         2368           20469         False 2020-12-12
# 1           4056            6               3          True 2020-12-12
# 2           1151         4301           95963         False 2020-12-12
# 3         278080          116             765          True 2020-12-12
# 4            625          477           14475         False 2020-12-20
#
#                                                 text  \
# 0  #CovidVaccine \n\nStates will start getting #C...
# 1  Coronavirus: Iran reports 8,201 new cases, 221...
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 4  When The #CovidVaccine \nPoisons Enough Of The...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 1          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 2                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 3           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
# 4                     ['CovidVaccine', 'BellsPalsy']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 1        3         5      False  [34.9249653, 38.9597594]
# 2        0         2      False  [-0.1276474, 51.5073219]
# 3        1         1      False  [29.2675469, 26.2540493]
# 4        0         0      False   [5.9799001, 51.4371483]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 1  38.9597594, 34.9249653          Turkey
# 2  51.5073219, -0.1276474  United Kingdom
# 3  26.2540493, 29.2675469           Egypt
# 4   51.4371483, 5.9799001     Netherlands
#
#                                        modified_text  sent_score sentiment  \
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 1  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 4  When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral
#
#        cases
# 0  4675036.0
# 1  4675036.0
# 2  4675036.0
# 3  4675036.0
# 4  3906009.0

# %%
filt_deaths.head()
# Out:
#           Date  Daily new confirmed deaths due to COVID-19
# 325 2020-12-12                                     78057.0
# 326 2020-12-13                                     55661.0
# 327 2020-12-14                                     68538.0
# 328 2020-12-15                                    103882.0
# 329 2020-12-16                                    101136.0

# %%
filt_df.shape
# Out:
# (9340, 23)

# %%
filt_deaths.columns = ['date', 'Daily new confirmed deaths due to COVID-19']
filt_deaths
# Out:
#           date  Daily new confirmed deaths due to COVID-19
# 325 2020-12-12                                     78057.0
# 326 2020-12-13                                     55661.0
# 327 2020-12-14                                     68538.0
# 328 2020-12-15                                    103882.0
# 329 2020-12-16                                    101136.0
# ..         ...                                         ...
# 452 2021-04-18                                     64935.0
# 453 2021-04-19                                     79137.0
# 454 2021-04-20                                    105818.0
# 455 2021-04-21                                    105465.0
# 456 2021-04-22                                    102643.0
#
# [132 rows x 2 columns]

# %%
filt_df
# Out:
#                        id                  user_name  user_location  \
# 0     1337842295857623042               Ch.Amjad Ali      Islamabad
# 1     1337783770070409218                      ILKHA        Türkiye
# 2     1337760271151063040                Andy Thomas         London
# 3     1337727767551553536           Daily News Egypt          Egypt
# 4     1340571472025141248                     IP_Man        America
# ...                   ...                        ...            ...
# 9335  1382253724878344196                     Roopam         Ranchi
# 9336  1382250817189597189               moneycontrol         Mumbai
# 9337  1382250738760384515                     ET NOW          India
# 9338  1382248484259123205  Russian Mission in Geneva         Geneve
# 9339  1382246393532801026                Mora Mosese  NtswanaTsatsi
#
#                                        user_description         user_created  \
# 0     #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 1        Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 2                Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 3     Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 4     One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
# ...                                                 ...                  ...
# 9335  Be Ur Kind of Crazy....Someone out there will ...  2019-08-19 14:55:44
# 9336  Moneycontrol is India’s No. 1 financial portal...  2009-08-26 07:55:29
# 9337  Youtube: https://t.co/u54RR8zcQ8 Facebook: htt...  2010-12-10 12:49:29
# 9338  Постпредство России при Отделении ООН и др. ме...  2011-07-26 08:40:47
# 9339                               #MoAfrika - #MoSotho  2019-12-06 11:11:07
#
#      user_followers user_friends user_favourites user_verified       date  \
# 0               671         2368           20469         False 2020-12-12
# 1              4056            6               3          True 2020-12-12
# 2              1151         4301           95963         False 2020-12-12
# 3            278080          116             765          True 2020-12-12
# 4               625          477           14475         False 2020-12-20
# ...             ...          ...             ...           ...        ...
# 9335            304          280              87         False 2021-04-14
# 9336        1077795          297            1079          True 2021-04-14
# 9337         641608           79               3          True 2021-04-14
# 9338           9862          589            3502          True 2021-04-14
# 9339            164          101            6465         False 2021-04-14
#
#                                                    text  \
# 0     #CovidVaccine \n\nStates will start getting #C...
# 1     Coronavirus: Iran reports 8,201 new cases, 221...
# 2     @ZubyMusic 6 deaths so far. \nIt's only death,...
# 3     #FDA authorizes #PfizerBioNTech #coronavirus v...
# 4     When The #CovidVaccine \nPoisons Enough Of The...
# ...                                                 ...
# 9335  Mr. @RahulGandhi it is not because of you but ...
# 9336  .@viswanath_pilla looks at how #SputnikV stack...
# 9337  Watch @drreddys address #SputnikV EUA #LIVE  h...
# 9338  ✅ 🇷🇺#Gamaleya Research Center in cooperation w...
# 9339  @FloydShivambu #SputnikV. Where are #AfricanEx...
#
#                                                hashtags                source  \
# 0     ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...       Twitter Web App
# 1             ['Iran', 'coronavirus', 'PfizerBioNTech']             TweetDeck
# 2                    ['CovidVaccines', 'Pfizervaccine']   Twitter for Android
# 3              ['FDA', 'PfizerBioNTech', 'coronavirus']       Twitter Web App
# 4                        ['CovidVaccine', 'BellsPalsy']       Twitter Web App
# ...                                                 ...                   ...
# 9335                                       ['SputnikV']       Twitter Web App
# 9336              ['SputnikV', 'Covishield', 'Covaxin']       Twitter Web App
# 9337                               ['SputnikV', 'LIVE']  Twitter Media Studio
# 9338                                       ['Gamaleya']    Twitter for iPhone
# 9339      ['SputnikV', 'AfricanExpertise', 'ShamDemic']       Twitter Web App
#
#      retweets favorites is_retweet           user_coordinates  \
# 0           0         0      False   [73.0651511, 33.6938118]
# 1           3         5      False   [34.9249653, 38.9597594]
# 2           0         2      False   [-0.1276474, 51.5073219]
# 3           1         1      False   [29.2675469, 26.2540493]
# 4           0         0      False    [5.9799001, 51.4371483]
# ...       ...       ...        ...                        ...
# 9335        0         2      False   [85.3250132, 23.3700354]
# 9336        2         4      False   [72.8773928, 19.0759899]
# 9337        1        10      False   [78.6677428, 22.3511148]
# 9338        2         9      False    [6.1466014, 46.2017559]
# 9339        0         0      False  [28.8554121, -27.2286065]
#
#             user_coordinates2    user_country  \
# 0      33.6938118, 73.0651511        Pakistan
# 1      38.9597594, 34.9249653          Turkey
# 2      51.5073219, -0.1276474  United Kingdom
# 3      26.2540493, 29.2675469           Egypt
# 4       51.4371483, 5.9799001     Netherlands
# ...                       ...             ...
# 9335   23.3700354, 85.3250132           India
# 9336   19.0759899, 72.8773928           India
# 9337   22.3511148, 78.6677428           India
# 9338    46.2017559, 6.1466014     Switzerland
# 9339  -27.2286065, 28.8554121    South Africa
#
#                                           modified_text  sent_score sentiment  \
# 0     #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 1     Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 2     @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 3     #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 4     When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral
# ...                                                 ...         ...       ...
# 9335  Mr. @RahulGandhi it is not because of you but ...    0.000000   neutral
# 9336  .@viswanath_pilla looks at how #SputnikV stack...    0.000000   neutral
# 9337  Watch @drreddys address #SputnikV EUA #LIVE  h...    0.136364  positive
# 9338  ✅ 🇷🇺#Gamaleya Research Center in cooperation w...   -0.100000  negative
# 9339  @FloydShivambu #SputnikV. Where are #AfricanEx...    0.100000  positive
#
#           cases
# 0     4675036.0
# 1     4675036.0
# 2     4675036.0
# 3     4675036.0
# 4     3906009.0
# ...         ...
# 9335  6243243.0
# 9336  6243243.0
# 9337  6243243.0
# 9338  6243243.0
# 9339  6243243.0
#
# [9340 rows x 23 columns]

# %%
filt_df['deaths'] = 0
filt_df.head()
# Out:
#                     id         user_name user_location  \
# 0  1337842295857623042      Ch.Amjad Ali     Islamabad
# 1  1337783770070409218             ILKHA       Türkiye
# 2  1337760271151063040       Andy Thomas        London
# 3  1337727767551553536  Daily News Egypt         Egypt
# 4  1340571472025141248            IP_Man       America
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 1     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 2             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 3  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 4  One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
#
#   user_followers user_friends user_favourites user_verified       date  \
# 0            671         2368           20469         False 2020-12-12
# 1           4056            6               3          True 2020-12-12
# 2           1151         4301           95963         False 2020-12-12
# 3         278080          116             765          True 2020-12-12
# 4            625          477           14475         False 2020-12-20
#
#                                                 text  \
# 0  #CovidVaccine \n\nStates will start getting #C...
# 1  Coronavirus: Iran reports 8,201 new cases, 221...
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 4  When The #CovidVaccine \nPoisons Enough Of The...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 1          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 2                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 3           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
# 4                     ['CovidVaccine', 'BellsPalsy']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 1        3         5      False  [34.9249653, 38.9597594]
# 2        0         2      False  [-0.1276474, 51.5073219]
# 3        1         1      False  [29.2675469, 26.2540493]
# 4        0         0      False   [5.9799001, 51.4371483]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 1  38.9597594, 34.9249653          Turkey
# 2  51.5073219, -0.1276474  United Kingdom
# 3  26.2540493, 29.2675469           Egypt
# 4   51.4371483, 5.9799001     Netherlands
#
#                                        modified_text  sent_score sentiment  \
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 1  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 4  When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral
#
#        cases  deaths
# 0  4675036.0       0
# 1  4675036.0       0
# 2  4675036.0       0
# 3  4675036.0       0
# 4  3906009.0       0

# %%
for index, row in filt_df.iterrows():
    filt_df.loc[index,'deaths'] = filt_deaths.loc[filt_deaths['date'] == row.date].iloc[0]['Daily new confirmed deaths due to COVID-19']

# %%
filt_df.head()
# Out:
#                     id         user_name user_location  \
# 0  1337842295857623042      Ch.Amjad Ali     Islamabad
# 1  1337783770070409218             ILKHA       Türkiye
# 2  1337760271151063040       Andy Thomas        London
# 3  1337727767551553536  Daily News Egypt         Egypt
# 4  1340571472025141248            IP_Man       America
#
#                                     user_description         user_created  \
# 0  #ProudPakistani #LovePakArmy #PMIK @insafiansp...  2012-11-12 04:18:12
# 1     Official Twitter account of Ilke News Agency /  2015-05-22 08:31:12
# 2             Retweets not necessarily endorsements.  2009-03-07 20:39:15
# 3  Egypt's Only Daily Independent Newspaper in En...  2009-04-26 07:56:24
# 4  One Man, \nWith One Statistically Impossible G...  2012-06-21 01:41:33
#
#   user_followers user_friends user_favourites user_verified       date  \
# 0            671         2368           20469         False 2020-12-12
# 1           4056            6               3          True 2020-12-12
# 2           1151         4301           95963         False 2020-12-12
# 3         278080          116             765          True 2020-12-12
# 4            625          477           14475         False 2020-12-20
#
#                                                 text  \
# 0  #CovidVaccine \n\nStates will start getting #C...
# 1  Coronavirus: Iran reports 8,201 new cases, 221...
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...
# 4  When The #CovidVaccine \nPoisons Enough Of The...
#
#                                             hashtags               source  \
# 0  ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 1          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 2                 ['CovidVaccines', 'Pfizervaccine']  Twitter for Android
# 3           ['FDA', 'PfizerBioNTech', 'coronavirus']      Twitter Web App
# 4                     ['CovidVaccine', 'BellsPalsy']      Twitter Web App
#
#   retweets favorites is_retweet          user_coordinates  \
# 0        0         0      False  [73.0651511, 33.6938118]
# 1        3         5      False  [34.9249653, 38.9597594]
# 2        0         2      False  [-0.1276474, 51.5073219]
# 3        1         1      False  [29.2675469, 26.2540493]
# 4        0         0      False   [5.9799001, 51.4371483]
#
#         user_coordinates2    user_country  \
# 0  33.6938118, 73.0651511        Pakistan
# 1  38.9597594, 34.9249653          Turkey
# 2  51.5073219, -0.1276474  United Kingdom
# 3  26.2540493, 29.2675469           Egypt
# 4   51.4371483, 5.9799001     Netherlands
#
#                                        modified_text  sent_score sentiment  \
# 0  #CovidVaccine \n\nStates will start getting #C...    0.000000   neutral
# 1  Coronavirus: Iran reports 8,201 new cases, 221...    0.068182  positive
# 2  @ZubyMusic 6 deaths so far. \nIt's only death,...    0.050000  positive
# 3  #FDA authorizes #PfizerBioNTech #coronavirus v...    0.000000   neutral
# 4  When The #CovidVaccine \nPoisons Enough Of The...    0.000000   neutral
#
#        cases   deaths
# 0  4675036.0  78057.0
# 1  4675036.0  78057.0
# 2  4675036.0  78057.0
# 3  4675036.0  78057.0
# 4  3906009.0  58657.0

# %%
filt_df.to_csv('Data/vt_cases_deaths_complete.csv', index = False)
